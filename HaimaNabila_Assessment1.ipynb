# %% [markdown]
# <a href="https://colab.research.google.com/github/haimanabila/DLCV_Workshop/blob/main/HaimaNabila_Assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assessment 1: Deep Learning
#
# 1) Answer all questions.
# 2) This assessment is open-book. You are allowed to refer to any references including online materials, books, notes, codes, github links, etc.
# 3) Copy this notebook to your google drive (click **FILE** > **save a copy in Drive**)
# 4) Upload the answer notebook to your github.
# 5) Submit the assessment by sharing the link to your answer notebook.

# %% [markdown]
# **QUESTION 1**
#
# One day while wandering around a clothing store at KL East Mall, you stumbled upon a pretty girl who is choosing a dress for Hari Raya. It turns out that the girl is visually impaired and had a hard time distinguishing between an abaya and a kebaya. To help people with the similar situation, you then decided to develop an AI system to identify the type of clothes using a Convolutional Neural Networks (ConvNet). In order to train the network, you decide to use the Fashion MNIST dataset which is freely available on Pytorch.

# %% [markdown]
# a) Given the problem, what is the most appropriate loss function to use? Justify your answer. **[5 marks]**

# %% [markdown]
# <span style="color:blue">
#     ANSWER:  For this task, it is a multiclass classification task where the output are the Fashion MNIST dataset classes. Hence, Multi-Class Cross-Entropy Loss are the most appropriate loss function to use. Cross-entropy will calculate a score that summarizes the average difference between the actual and predicted probability distributions for all classes in the problem. The score is minimized and a perfect cross-entropy value is 0.And the final layer output should be passed through a softmax activation so that each node output a probability value between (0–1). This could be helpful in order to distinguish clothes types among multiple class. </span>

# %% [markdown]
# b) Create and train a ConvNet corresponding to the following CNN architecture (with a modification of the final layer to address the number of classes). Please include **[10 marks]**:
#
#     1) The dataloader to load the train and test datasets.
#
#     2) The model definition (either using sequential method OR pytorch class method).
#
#     3) Define your training loop.
#
#     4) Output the mean accuracy for the whole testing dataset.
#
#
#
# <div>
# <img src="https://vitalflux.com/wp-content/uploads/2021/11/VGG16-CNN-Architecture.png" width="550"/>
# </div>

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary

# %%
###############################################
############### YOUR CODES HERE ###############
###############################################

# %%
import torch.nn.functional as F

# Define a transform to convert to images to tensor and normalize

from torch.utils.data.sampler import SubsetRandomSampler 
image_transforms = {
    'train': transforms.Compose([
        #transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        #transforms.RandomRotation(degrees=15),
        #transforms.RandomHorizontalFlip(),
        #transforms.CenterCrop(size = 224),
        transforms.Resize(size = (224, 224)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.size(0)==1 else x),
        transforms.Normalize([0.5, 0.5, 0.5],
                             [0.5, 0.5, 0.5])
    ]),

    'test': transforms.Compose([
        #transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        #transforms.CenterCrop(size = 224),
        transforms.Resize(size = (224, 224)), 
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.size(0)==1 else x),
        transforms.Normalize([0.5, 0.5, 0.5],
                             [0.5, 0.5, 0.5])
    ])
  }

batchSize = 10

data = {
    'train': datasets.FashionMNIST('~/.pytorch/F_MNIST_data', download=True, train=True, transform=image_transforms['train']),

    'test': datasets.FashionMNIST('~/.pytorch/F_MNIST_data', download=True, train=False, transform=image_transforms['test'])
}

from torch.utils.data import DataLoader

# Use custom created train Dataset
trainloader = DataLoader(dataset=data['train'], 
                                     batch_size=10, 
                                     num_workers=0,
                                     shuffle=True)

# Use custom created test Dataset
testloader = DataLoader(dataset=data['test'], 
                                    batch_size=10, 
                                    num_workers=0, 
                                    shuffle=False)

train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

print(train_data_size)
print(test_data_size)

class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        # I have changed the Grayscale to RGB, hence the first input channels is 3
        self.conv1 = nn.Conv2d(3, 64, 1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(64, 128, 1)
        #self.pool = nn.MaxPool2d(2, 2)
        self.conv3 = nn.Conv2d(128, 256, 1)
        #self.pool = nn.MaxPool2d(2, 2)
        self.conv4 = nn.Conv2d(256, 512, 1)
        #self.pool = nn.MaxPool2d(2, 2)
        self.conv5 = nn.Conv2d(512, 512, 1)
        #self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(512 * 7 * 7, 1000) 
        self.fc2 = nn.Linear(1000, 4096)
        self.fc3 = nn.Linear(4096, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.pool(self.relu(self.conv3(x)))
        x = self.pool(self.relu(self.conv4(x)))
        x = self.pool(self.relu(self.conv5(x)))
        #print (x.shape)
        x = x.view(-1, 512 * 7 * 7)
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

model = CNN() 
# To instantiate the network to be used in instance method
# Out:
# 60000
# 10000

# %%
# 2. LOSS AND OPTIMIZER
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9)

# %%
# 3. MOVE THE MODEL TO GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# CNN(
#   (conv1): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#   (conv3): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1))
#   (conv4): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1))
#   (conv5): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1))
#   (fc1): Linear(in_features=25088, out_features=1000, bias=True)
#   (fc2): Linear(in_features=1000, out_features=4096, bias=True)
#   (fc3): Linear(in_features=4096, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %%
# To calculate training time

import time 

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''

    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'cifar10_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
# 4. Train the model for 5 epochs

num_epochs = 5
trained_model, history = train_and_validate(model, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/5
# Epoch : 000, Training: Loss: 2.3235, Accuracy: 10.1317%,
# 		Validation : Loss : 2.3234, Accuracy: 10.0000%, Time: 273.5568s
# Epoch: 2/5
# Epoch : 001, Training: Loss: 2.3264, Accuracy: 9.9167%,
# 		Validation : Loss : 2.3226, Accuracy: 10.0000%, Time: 271.4964s
# Epoch: 3/5
# Epoch : 002, Training: Loss: 2.3254, Accuracy: 9.8583%,
# 		Validation : Loss : 2.3133, Accuracy: 10.0000%, Time: 270.7989s
# Epoch: 4/5
# Epoch : 003, Training: Loss: 2.3254, Accuracy: 9.8667%,
# 		Validation : Loss : 2.3276, Accuracy: 10.0000%, Time: 272.6220s
# Epoch: 5/5
# Epoch : 004, Training: Loss: 2.3255, Accuracy: 9.8767%,
# 		Validation : Loss : 2.3088, Accuracy: 10.0000%, Time: 271.4951s

# %%
# 5. Analyze the loss curve

history = np.array(history)
plt.plot(history[:,0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0,3)
# plt.savefig('cifar10_loss_curve.png')
plt.show()

# %%
# 6. Analyze the accuracy curve

history = np.array(history)
plt.plot(history[:,2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0,1)
# plt.savefig('cifar10_accuracy_curve.png')
plt.show()

# %% [markdown]
# c) Replace your defined CNN in b) with a pre-trained model. Then, proceed with a transfer learning and finetune the model for the Fashion MNIST dataset. **[10 marks]**

# %%
###############################################
###############YOUR CODES HERE ################
###############################################

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary

import torch.nn.functional as F
from torch.utils.data.sampler import  SubsetRandomSampler#Define a transform to convert to images to tensor and normalize
image_transforms = {
    'train': transforms.Compose([
        #transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        #transforms.RandomRotation(degrees=15),
        #transforms.RandomHorizontalFlip(),
        #transforms.CenterCrop(size=224),
        transforms.Resize(size=(112,112)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.size(0)==1 else x),
        transforms.Normalize([0.5, 0.5, 0.5],
                             [0.5, 0.5, 0.5])
    ]),

    'test': transforms.Compose([
        #transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
        #transforms.CenterCrop(size=224),
        transforms.Resize(size=(112,112)),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.size(0)==1 else x),
        transforms.Normalize([0.5, 0.5, 0.5],
                             [0.5, 0.5, 0.5])
    ])
  }

batchSize = 8

data = {
    'train': datasets.FashionMNIST('~/.pytorch/F_MNIST_data', download=True, train=True, transform=image_transforms['train']),

    'test': datasets.FashionMNIST('~/.pytorch/F_MNIST_data', download=True, train=False, transform=image_transforms['test'])
}

from torch.utils.data import DataLoader
trainloader = DataLoader(dataset=data['train'], # Use custom created train Dataset
                                     batch_size=4, # How many samples per batch
                                     num_workers=0, # How many subprocesses to use for data loading? (higher = more)
                                     shuffle=True)

testloader = DataLoader(dataset=data['test'], # Use custom created test Dataset
                                    batch_size=4, 
                                    num_workers=0, 
                                    shuffle=False)

train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

print(train_data_size)
print(test_data_size)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)

model_ft = models.resnet18(pretrained=True)  #if False, the weight will randomly initialized
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 10.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 10)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.0009, momentum=0.9)

import time
# To calculate training time

def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    '''
    Function to train and validate
    Parameters
        :param model: Model to train and validate
        :param loss_criterion: Loss Criterion to minimize
        :param optimizer: Optimizer for computing gradients
        :param epochs: Number of epochs (default=25)
  
    Returns
        model: Trained Model with best validation accuracy
        history: (dict object): Having training loss, accuracy and validation loss, accuracy
    '''
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))
            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'cifar10_model_'+str(epoch)+'.pt')
            
    return model, history
# Out:
# 60000
# 10000
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# 4. Train the model for 5 epochs

num_epochs = 5
trained_model, history = train_and_validate(model_ft, criterion, optimizer_ft, num_epochs)
# Out:
# Epoch: 1/5
# Epoch : 000, Training: Loss: 0.3958, Accuracy: 86.6500%,
# 		Validation : Loss : 0.2328, Accuracy: 91.6300%, Time: 215.4669s
# Epoch: 2/5
# Epoch : 001, Training: Loss: 0.2299, Accuracy: 92.1417%,
# 		Validation : Loss : 0.2084, Accuracy: 92.6300%, Time: 215.6069s
# Epoch: 3/5
# Epoch : 002, Training: Loss: 0.1804, Accuracy: 93.7000%,
# 		Validation : Loss : 0.1780, Accuracy: 93.7700%, Time: 217.4330s
# Epoch: 4/5
# Epoch : 003, Training: Loss: 0.1483, Accuracy: 94.8850%,
# 		Validation : Loss : 0.1684, Accuracy: 93.8900%, Time: 216.2565s
# Epoch: 5/5
# Epoch : 004, Training: Loss: 0.1229, Accuracy: 95.6867%,
# 		Validation : Loss : 0.1845, Accuracy: 93.5800%, Time: 218.4354s

# %% [markdown]
# d) Using model-centric methods, propose two (2) strategies that can be used to increase the accuracy of the model on the testing dataset. **[5 marks]**
#
#
# <span style="color:blue">
#     Two model-centric techniques that I propose are:
#
# 1.   Adding Batch Normalization in Convolution Layer
# 2.   Adding Dropout in Fully-connected Layer
#
# </span>

# %% [markdown]
# e) Next, implement the two proposed model-centric techniques for the same problem as in the previous question. **[15 marks]**

# %%
###############################################
############## YOUR CODES HERE ################
###############################################

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary

# %%
# 1) The dataloader to load the train and test datasets.
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Resize(size=(224,224)),
     transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.size(0)==1 else x),
     # To convert 1 chanel image to 3 chanel
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
     ])

batch_size = 64

trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('Tshirt', 'Trouser', 'Pullover', 'Dress',
       'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot')
train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/26421880 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/29515 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/4422102 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/5148 [00:00<?, ?it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
# 2) The model definition (either using sequential method OR pytorch class method).
class AlexNet(nn.Module):
    def __init__(self, num_classes: int = 1000) -> None:
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )

        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

model = AlexNet(num_classes=10)
inp = torch.rand(1,3,128,128)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
# 3) Define the training loop.
def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'FashionMNIST_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
# Train the model for 5 epochs

num_epochs = 3
trained_model, history = train_and_validate(model, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/3
# Epoch : 000, Training: Loss: 0.5128, Accuracy: 80.9383%,
# 		Validation : Loss : 0.4546, Accuracy: 83.2800%, Time: 138.6314s
# Epoch: 2/3
# Epoch : 001, Training: Loss: 0.4384, Accuracy: 83.7433%,
# 		Validation : Loss : 0.4072, Accuracy: 85.1500%, Time: 130.4306s
# Epoch: 3/3
# Epoch : 002, Training: Loss: 0.3936, Accuracy: 85.5067%,
# 		Validation : Loss : 0.3667, Accuracy: 86.1800%, Time: 130.7164s

# %% [markdown]
# f) Do you see any accuracy improvement? Whether it is a "yes" or "no", discuss the possible reasons contributing to the accuracy improvement/ unimprovement. **[5 marks]**
#
# <span style="color:blue">
#     No. This may due to the low epoch of training as the train is run only for 3 epochs due to time constraint. Next, the second model maybe a bit more complex than the it should be. Overfitting still happended even we add dropout and it does not help to increase the mean accuracy of the model compared to Resnet. </span>

# %% [markdown]
# g) In real applications, data-centric strategies are essential to train robust deep learning models. Give two (2) examples of such strategies and discuss how the strategies helps improving the model accuracy. **[5 marks]**
#
# <span style="color:blue">
#
#
# 1. Increasing the data's variety. This will increase the model's ability to accommodate different viewpoints and lighting conditions of the same object.
# 3. Remove irrelevant data images so that the data quality can be improved. By doing this, the data's noise will be reduced.</span>

# %% [markdown]
# h) Next, implement the two proposed data-centric techniques for the same problem as in the previous question. **[10 marks]**

# %%
###############################################
##############YOUR CODES HERE #################
###############################################

# %%
import torch, torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import time
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import glob
import numpy
import random

from PIL import Image
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, models, transforms
from torchsummary import summary

# 1) The dataloader to load the train and test datasets.
transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(size=(256,256)),
        transforms.RandomRotation(degrees=15),
        transforms.RandomHorizontalFlip(),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.size(0)==1 else x),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize(size=(256,256)),
        transforms.CenterCrop(size=224),
        transforms.ToTensor(),
        transforms.Lambda(lambda x: x.repeat(3, 1, 1) if x.size(0)==1 else x),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])
    ])
}

batch_size = 64

trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)

classes = ('Tshirt', 'Trouser', 'Pullover', 'Dress',
       'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle Boot')
train_data_size = len(trainloader.dataset)
test_data_size = len(testloader.dataset)

# %%
# 2) The model definition (either using sequential method OR pytorch class method)

class AlexNet(nn.Module):
    def __init__(self, num_classes: int = 1000) -> None:
        super(AlexNet, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(64, 192, kernel_size=5, padding=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(192, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )

        self.avgpool = nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = nn.Sequential(
            nn.Dropout(),
            nn.Linear(256 * 6 * 6, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

model = AlexNet(num_classes=10)
inp = torch.rand(1,3,128,128)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model.to(device)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace=True)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
#3) Define the training loop.
def train_and_validate(model, loss_criterion, optimizer, epochs=25):
    
    start = time.time()
    history = []
    best_acc = 0.0

    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
        
        # Set to training mode
        model.train()
        
        # Loss and Accuracy within the epoch
        train_loss = 0.0
        train_acc = 0.0
        
        valid_loss = 0.0
        valid_acc = 0.0
        
        for i, (inputs, labels) in enumerate(trainloader):

            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Clean existing gradients
            optimizer.zero_grad()
            
            # Forward pass - compute outputs on input data using the model
            outputs = model(inputs)
            
            # Compute loss
            loss = loss_criterion(outputs, labels)
            
            # Backpropagate the gradients
            loss.backward()
            
            # Update the parameters
            optimizer.step()
            
            # Compute the total loss for the batch and add it to train_loss
            train_loss += loss.item() * inputs.size(0)
            
            # Compute the accuracy
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
            
            # Convert correct_counts to float and then compute the mean
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
            
            # Compute total accuracy in the whole batch and add to train_acc
            train_acc += acc.item() * inputs.size(0)
            
            #print("Batch number: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()))

            
        # Validation - No gradient tracking needed
        with torch.no_grad():

            # Set to evaluation mode
            model.eval()

            # Validation loop
            for j, (inputs, labels) in enumerate(testloader):
                inputs = inputs.to(device)
                labels = labels.to(device)

                # Forward pass - compute outputs on input data using the model
                outputs = model(inputs)

                # Compute loss
                loss = loss_criterion(outputs, labels)

                # Compute the total loss for the batch and add it to valid_loss
                valid_loss += loss.item() * inputs.size(0)

                # Calculate validation accuracy
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))

                # Convert correct_counts to float and then compute the mean
                acc = torch.mean(correct_counts.type(torch.FloatTensor))

                # Compute total accuracy in the whole batch and add to valid_acc
                valid_acc += acc.item() * inputs.size(0)

                #print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()))
            
        # Find average training loss and training accuracy
        avg_train_loss = train_loss/train_data_size 
        avg_train_acc = train_acc/train_data_size

        # Find average training loss and training accuracy
        avg_test_loss = valid_loss/test_data_size 
        avg_test_acc = valid_acc/test_data_size

        history.append([avg_train_loss, avg_test_loss, avg_train_acc, avg_test_acc])
                
        epoch_end = time.time()
    
        print("Epoch : {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation : Loss : {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(epoch, avg_train_loss, avg_train_acc*100, avg_test_loss, avg_test_acc*100, epoch_end-epoch_start))
        
        # Save if the model has best accuracy till now
        torch.save(model, 'FashionMNIST_model_'+str(epoch)+'.pt')
            
    return model, history

# %%
num_epochs = 5
trained_model, history = train_and_validate(model, criterion, optimizer, num_epochs)
# Out:
# Epoch: 1/5
# Epoch : 000, Training: Loss: 2.1942, Accuracy: 17.2600%,
# 		Validation : Loss : 1.0314, Accuracy: 60.0900%, Time: 131.0961s
# Epoch: 2/5
# Epoch : 001, Training: Loss: 0.7519, Accuracy: 71.4183%,
# 		Validation : Loss : 0.5942, Accuracy: 78.1800%, Time: 131.4682s
# Epoch: 3/5
# Epoch : 002, Training: Loss: 0.5303, Accuracy: 80.1717%,
# 		Validation : Loss : 0.4922, Accuracy: 81.4100%, Time: 131.1119s
# Epoch: 4/5
# Epoch : 003, Training: Loss: 0.4480, Accuracy: 83.4300%,
# 		Validation : Loss : 0.4229, Accuracy: 84.5600%, Time: 131.8536s
# Epoch: 5/5
# Epoch : 004, Training: Loss: 0.3999, Accuracy: 85.2800%,
# 		Validation : Loss : 0.3772, Accuracy: 86.1900%, Time: 131.1856s

# %% [markdown]
# **QUESTION 2** **[35 marks]**
#
# Firstly, watch this video:
#
# https://drive.google.com/file/d/1bsypahR7I3f_R3DXkfw_tf0BrbCHxE_O/view?usp=sharing
#
# This video shows an example of masked face recognition where the deep learning model is able to detect and classify your face even when wearing a face mask. Using the end-to-end object detection pipeline that you have learned, develop your own masked face recognition such that the model should recognize your face even on face mask while recognize other persons as "others".
#
# Deliverables for this question are:
#
# - the model file. Change the name to <your_name>.pt file (e.g. hasan.pt).
# - a short video (~10 secs) containing your face and your friends faces (for inference).

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12975, done.
# remote: Counting objects: 100% (131/131), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 12975 (delta 81), reused 100 (delta 60), pack-reused 12844
# Receiving objects: 100% (12975/12975), 13.11 MiB | 14.11 MiB/s, done.
# Resolving deltas: 100% (8916/8916), done.
# /content/yolov5
#      |████████████████████████████████| 1.6 MB 13.9 MB/s
#      |████████████████████████████████| 145 kB 13.4 MB/s
#      |████████████████████████████████| 178 kB 82.9 MB/s
#      |████████████████████████████████| 1.1 MB 85.1 MB/s
#      |████████████████████████████████| 67 kB 6.3 MB/s
#      |████████████████████████████████| 54 kB 2.8 MB/s
#      |████████████████████████████████| 138 kB 87.0 MB/s
#      |████████████████████████████████| 62 kB 1.7 MB/s
#   Building wheel for roboflow (setup.py) ... done
#   Building wheel for wget (setup.py) ... done

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.12.1+cu113 (CPU)

# %%
from roboflow import Roboflow
rf = Roboflow(model_format="yolov5", notebook="ultralytics")

# Set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CTj7BvhxVznGG5ewX65p")
project = rf.workspace("dlcv-emxa8").project("my_face_detection")
dataset = project.version(1).download("yolov5")
# Out:
# upload and label your dataset, and get an API KEY here: https://app.roboflow.com/?model=yolov5&ref=ultralytics
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: roboflow in /usr/local/lib/python3.7/dist-packages (0.2.15)
# Requirement already satisfied: urllib3==1.26.6 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.26.6)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (6.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.64.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.21.0)
# Requirement already satisfied: certifi==2021.5.30 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2021.5.30)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.21.6)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2)
# Requirement already satisfied: opencv-python-headless>=4.5.1.48 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.6.0.66)
# Requirement already satisfied: kiwisolver==1.3.1 in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.3.1)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.9.1)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (4.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from roboflow) (3.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from roboflow) (1.15.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.10.0)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (7.1.2)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.4.7)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.7/dist-packages (from roboflow) (0.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.28.1)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from roboflow) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->roboflow) (2.1.1)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in /content/datasets/My_Face_Detection-1 to yolov5pytorch: 100% [916316 / 916316] bytes
# Extracting Dataset Version Zip to /content/datasets/My_Face_Detection-1 in yolov5pytorch:: 100%|██████████| 92/92 [00:00<00:00, 2826.62it/s]

# %%
# !python train.py --img 416 --batch 16 --epochs 150 --data {dataset.location}/data.yaml --weights yolov5s.pt --cache

# Start tensorboard
# Launch after you have started training
# Logs save in the folder "runs"
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/datasets/My_Face_Detection-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-180-g82bec4c Python-3.7.14 torch-1.12.1+cu113 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs in Weights & Biases
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 31.0MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 140MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7027720 parameters, 7027720 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/content/datasets/My_Face_Detection-1/train/labels' images and labels...27 found, 0 missing, 0 empty, 0 corrupt: 100% 27/27 [00:00<00:00, 402.97it/s]
# train: New cache created: /content/datasets/My_Face_Detection-1/train/labels.cache
# train: Caching images (0.0GB ram): 100% 27/27 [00:00<00:00, 81.68it/s]
# val: Scanning '/content/datasets/My_Face_Detection-1/valid/labels' images and labels...7 found, 0 missing, 0 empty, 0 corrupt: 100% 7/7 [00:00<00:00, 39.20it/s]
# val: New cache created: /content/datasets/My_Face_Detection-1/valid/labels.cache
# val: Caching images (0.0GB ram): 100% 7/7 [00:00<00:00, 94.52it/s]
#
# AutoAnchor: 4.44 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/149         0G     0.1182    0.01886    0.04273         21        416: 100% 2/2 [00:23<00:00, 11.66s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.30s/it]
#                    all          7          7     0.0012     0.0833      0.008     0.0024
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/149         0G     0.1174    0.01795    0.04593         23        416: 100% 2/2 [00:16<00:00,  8.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.11s/it]
#                    all          7          7    0.00113     0.0833    0.00735    0.00294
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/149         0G     0.1119    0.01622    0.04084         12        416: 100% 2/2 [00:16<00:00,  8.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.04s/it]
#                    all          7          7    0.00108     0.0833     0.0068    0.00272
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/149         0G     0.1113    0.01901    0.04105         24        416: 100% 2/2 [00:16<00:00,  8.07s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.00s/it]
#                    all          7          7    0.00301       0.25     0.0328     0.0118
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/149         0G     0.1113    0.01876    0.04037         20        416: 100% 2/2 [00:18<00:00,  9.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.97s/it]
#                    all          7          7    0.00427      0.833    0.00786    0.00105
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/149         0G     0.1004    0.01817     0.0405         21        416: 100% 2/2 [00:16<00:00,  8.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.95s/it]
#                    all          7          7    0.00329       0.75     0.0268     0.0119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/149         0G     0.1031     0.0215    0.03944         21        416: 100% 2/2 [00:16<00:00,  8.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.86s/it]
#                    all          7          7    0.00496      0.917     0.0175    0.00302
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/149         0G    0.09146    0.02216    0.03502         22        416: 100% 2/2 [00:15<00:00,  7.98s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.84s/it]
#                    all          7          7    0.00478        0.5     0.0164    0.00306
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/149         0G    0.08994    0.02591    0.03289         29        416: 100% 2/2 [00:15<00:00,  7.84s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all          7          7    0.00525          1     0.0309    0.00521
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/149         0G    0.08654    0.02237    0.03273         18        416: 100% 2/2 [00:15<00:00,  7.93s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.73s/it]
#                    all          7          7    0.00511          1     0.0344    0.00552
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/149         0G     0.0878    0.02042     0.0302         20        416: 100% 2/2 [00:15<00:00,  7.92s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.77s/it]
#                    all          7          7    0.00416      0.917     0.0277    0.00612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/149         0G    0.08578     0.0211    0.02823         20        416: 100% 2/2 [00:17<00:00,  8.53s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.76s/it]
#                    all          7          7    0.00422      0.917     0.0192    0.00516
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/149         0G    0.08334    0.02431    0.02622         30        416: 100% 2/2 [00:15<00:00,  7.99s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all          7          7    0.00381      0.917      0.129     0.0218
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/149         0G    0.08547    0.02255    0.02743         19        416: 100% 2/2 [00:16<00:00,  8.08s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.71s/it]
#                    all          7          7    0.00374      0.917      0.123      0.017
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/149         0G    0.08273    0.02445    0.02479         21        416: 100% 2/2 [00:16<00:00,  8.07s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.71s/it]
#                    all          7          7    0.00422          1     0.0577     0.0115
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/149         0G    0.08215    0.01895    0.02707         18        416: 100% 2/2 [00:16<00:00,  8.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.72s/it]
#                    all          7          7    0.00433          1     0.0713     0.0152
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/149         0G    0.07773    0.02625    0.02202         27        416: 100% 2/2 [00:16<00:00,  8.05s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.68s/it]
#                    all          7          7    0.00436          1     0.0724     0.0168
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/149         0G    0.07853    0.02381    0.02084         23        416: 100% 2/2 [00:15<00:00,  7.93s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.57s/it]
#                    all          7          7     0.0043          1     0.0663     0.0176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/149         0G    0.07421    0.02132    0.01936         17        416: 100% 2/2 [00:15<00:00,  7.87s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.60s/it]
#                    all          7          7    0.00463          1     0.0708     0.0157
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/149         0G    0.07443    0.02243    0.02331         21        416: 100% 2/2 [00:17<00:00,  8.65s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.60s/it]
#                    all          7          7     0.0231        0.5      0.122      0.025
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/149         0G    0.07049    0.02718     0.0187         27        416: 100% 2/2 [00:15<00:00,  7.89s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all          7          7      0.582        0.5      0.228     0.0407
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/149         0G     0.0714    0.02698    0.01789         31        416: 100% 2/2 [00:16<00:00,  8.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.59s/it]
#                    all          7          7      0.605        0.5      0.336     0.0789
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/149         0G    0.07048    0.02039    0.01537         20        416: 100% 2/2 [00:15<00:00,  7.79s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.59s/it]
#                    all          7          7      0.652      0.438      0.201     0.0506
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/149         0G    0.07083    0.02371    0.01447         27        416: 100% 2/2 [00:15<00:00,  8.00s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.55s/it]
#                    all          7          7      0.774      0.207       0.36       0.13
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/149         0G    0.07282    0.02236    0.01505         20        416: 100% 2/2 [00:16<00:00,  8.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.57s/it]
#                    all          7          7      0.684      0.417      0.355     0.0689
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/149         0G    0.06613    0.02644     0.0121         31        416: 100% 2/2 [00:17<00:00,  8.76s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.56s/it]
#                    all          7          7      0.848      0.384      0.415      0.156
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/149         0G    0.06664    0.01865    0.01903         18        416: 100% 2/2 [00:16<00:00,  8.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all          7          7     0.0658      0.333     0.0934     0.0334
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/149         0G    0.07144    0.02205    0.01408         21        416: 100% 2/2 [00:17<00:00,  8.74s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.52s/it]
#                    all          7          7     0.0658      0.333     0.0934     0.0334
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/149         0G    0.06354    0.02077    0.01011         21        416: 100% 2/2 [00:16<00:00,  8.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.55s/it]
#                    all          7          7      0.788      0.333      0.564      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/149         0G    0.06116    0.02171     0.0118         22        416: 100% 2/2 [00:15<00:00,  8.00s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.574      0.333      0.108     0.0411
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/149         0G    0.07195    0.02126    0.01103         24        416: 100% 2/2 [00:15<00:00,  7.79s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.574      0.333      0.108     0.0411
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/149         0G    0.07037    0.01775    0.01078         20        416: 100% 2/2 [00:16<00:00,  8.22s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.52s/it]
#                    all          7          7      0.581      0.305      0.185     0.0487
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/149         0G    0.06954    0.01982    0.01393         21        416: 100% 2/2 [00:16<00:00,  8.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.57s/it]
#                    all          7          7     0.0912          1      0.205     0.0282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/149         0G    0.07102    0.02153    0.01307         25        416: 100% 2/2 [00:15<00:00,  7.98s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all          7          7     0.0912          1      0.205     0.0282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/149         0G    0.07432    0.01819   0.009492         22        416: 100% 2/2 [00:16<00:00,  8.00s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all          7          7     0.0939          1      0.214     0.0543
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/149         0G    0.06652       0.02    0.01243         21        416: 100% 2/2 [00:17<00:00,  8.73s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.52s/it]
#                    all          7          7      0.153          1      0.457      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/149         0G    0.06779    0.01768    0.01085         23        416: 100% 2/2 [00:16<00:00,  8.04s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.153          1      0.457      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/149         0G    0.06618     0.0193    0.01331         25        416: 100% 2/2 [00:16<00:00,  8.03s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.54s/it]
#                    all          7          7      0.112          1      0.666      0.196
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/149         0G    0.06654    0.01714    0.01279         19        416: 100% 2/2 [00:16<00:00,  8.03s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all          7          7       0.81      0.417      0.831      0.244
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/149         0G    0.06452    0.01632   0.006298         20        416: 100% 2/2 [00:16<00:00,  8.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7       0.81      0.417      0.831      0.244
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/149         0G    0.06392    0.01827    0.01031         22        416: 100% 2/2 [00:16<00:00,  8.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all          7          7      0.725      0.333      0.413      0.193
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/149         0G    0.06265    0.01903   0.007723         23        416: 100% 2/2 [00:16<00:00,  8.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.57s/it]
#                    all          7          7       0.74      0.417      0.569      0.233
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/149         0G    0.07224    0.01628    0.01129         20        416: 100% 2/2 [00:16<00:00,  8.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.31s/it]
#                    all          7          7       0.74      0.417      0.569      0.233
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/149         0G    0.07214    0.01766    0.01146         17        416: 100% 2/2 [00:16<00:00,  8.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7      0.276          1      0.607      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/149         0G    0.06088    0.01756   0.007086         23        416: 100% 2/2 [00:15<00:00,  7.98s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.276          1      0.607      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/149         0G    0.06458    0.01847   0.008638         20        416: 100% 2/2 [00:16<00:00,  8.29s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.53s/it]
#                    all          7          7      0.846      0.333      0.492      0.217
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/149         0G    0.06425    0.01759   0.008384         21        416: 100% 2/2 [00:16<00:00,  8.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.52s/it]
#                    all          7          7      0.846      0.333      0.492      0.217
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/149         0G    0.06638    0.01437   0.007927         18        416: 100% 2/2 [00:16<00:00,  8.33s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7      0.861      0.434      0.602      0.229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/149         0G    0.06162    0.01733    0.01234         26        416: 100% 2/2 [00:16<00:00,  8.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all          7          7      0.861      0.434      0.602      0.229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/149         0G    0.05852    0.01846   0.007661         19        416: 100% 2/2 [00:16<00:00,  8.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.449      0.333      0.557      0.262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/149         0G    0.07958    0.01537   0.007181         26        416: 100% 2/2 [00:17<00:00,  8.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.51s/it]
#                    all          7          7      0.449      0.333      0.557      0.262
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/149         0G    0.07576    0.01578   0.009515         18        416: 100% 2/2 [00:16<00:00,  8.31s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.304       0.39      0.464      0.222
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/149         0G    0.05786    0.01929   0.009994         21        416: 100% 2/2 [00:16<00:00,  8.37s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all          7          7      0.304       0.39      0.464      0.222
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/149         0G    0.05955    0.01633    0.01034         17        416: 100% 2/2 [00:16<00:00,  8.30s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.308          1      0.491      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/149         0G    0.05938    0.01633    0.00648         19        416: 100% 2/2 [00:16<00:00,  8.34s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all          7          7      0.308          1      0.491      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/149         0G    0.06409    0.01411   0.008231         19        416: 100% 2/2 [00:17<00:00,  8.54s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all          7          7      0.516       0.73      0.533      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/149         0G    0.05967    0.01439    0.01138         16        416: 100% 2/2 [00:16<00:00,  8.31s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.56s/it]
#                    all          7          7      0.516       0.73      0.533      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/149         0G    0.05777    0.01944   0.005966         24        416: 100% 2/2 [00:16<00:00,  8.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7       0.29       0.75       0.58      0.229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/149         0G     0.0576    0.01947   0.007563         27        416: 100% 2/2 [00:20<00:00, 10.03s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all          7          7       0.29       0.75       0.58      0.229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/149         0G    0.05616    0.01533   0.006212         19        416: 100% 2/2 [00:16<00:00,  8.40s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.52s/it]
#                    all          7          7      0.427       0.98      0.622      0.289
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/149         0G    0.05067    0.01582   0.007689         18        416: 100% 2/2 [00:16<00:00,  8.31s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all          7          7      0.427       0.98      0.622      0.289
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/149         0G    0.05226    0.01961   0.006526         22        416: 100% 2/2 [00:16<00:00,  8.19s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.595       0.75      0.621      0.261
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/149         0G    0.05958    0.01464   0.005498         17        416: 100% 2/2 [00:15<00:00,  7.91s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all          7          7      0.595       0.75      0.621      0.261
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/149         0G    0.06138    0.01531   0.005602         23        416: 100% 2/2 [00:16<00:00,  8.05s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all          7          7       0.64      0.926      0.723      0.469
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/149         0G    0.04855     0.0188   0.004854         23        416: 100% 2/2 [00:15<00:00,  7.97s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.33s/it]
#                    all          7          7       0.64      0.926      0.723      0.469
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/149         0G    0.04976    0.01786   0.006687         22        416: 100% 2/2 [00:17<00:00,  8.59s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all          7          7      0.631      0.899      0.971      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/149         0G    0.04916    0.01967   0.006059         23        416: 100% 2/2 [00:15<00:00,  7.86s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.631      0.899      0.971      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/149         0G    0.05045    0.01783   0.005254         22        416: 100% 2/2 [00:16<00:00,  8.00s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7        0.5       0.46      0.597      0.376
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/149         0G    0.05318    0.01609   0.004911         20        416: 100% 2/2 [00:16<00:00,  8.04s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7        0.5       0.46      0.597      0.376
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/149         0G    0.05898    0.01527   0.005904         26        416: 100% 2/2 [00:15<00:00,  7.70s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.35s/it]
#                    all          7          7      0.396          1      0.663       0.38
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/149         0G    0.04659    0.01658   0.003258         22        416: 100% 2/2 [00:15<00:00,  7.78s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all          7          7      0.396          1      0.663       0.38
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/149         0G    0.05177    0.01612   0.006231         19        416: 100% 2/2 [00:16<00:00,  8.00s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7      0.846      0.376      0.581      0.363
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/149         0G    0.04802    0.01598    0.00854         18        416: 100% 2/2 [00:15<00:00,  7.81s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all          7          7      0.846      0.376      0.581      0.363
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/149         0G    0.05033    0.01463   0.004392         19        416: 100% 2/2 [00:17<00:00,  8.69s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all          7          7      0.414      0.952      0.746      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/149         0G    0.05035     0.0139   0.003101         20        416: 100% 2/2 [00:15<00:00,  7.79s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.39s/it]
#                    all          7          7      0.414      0.952      0.746      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/149         0G    0.05017    0.01382   0.005044         15        416: 100% 2/2 [00:16<00:00,  8.23s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all          7          7      0.428      0.917      0.746      0.457
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/149         0G    0.04255    0.01477    0.00539         23        416: 100% 2/2 [00:16<00:00,  8.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.49s/it]
#                    all          7          7      0.428      0.917      0.746      0.457
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/149         0G    0.04826    0.01352   0.006982         12        416: 100% 2/2 [00:16<00:00,  8.22s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.502          1      0.726      0.393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/149         0G    0.05512     0.0141   0.003686         25        416: 100% 2/2 [00:16<00:00,  8.05s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.502          1      0.726      0.393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/149         0G    0.05269    0.01308   0.003831         22        416: 100% 2/2 [00:16<00:00,  8.14s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7      0.487      0.965      0.746      0.488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/149         0G    0.04695    0.01491     0.0125         17        416: 100% 2/2 [00:16<00:00,  8.11s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:02<00:00,  2.21s/it]
#                    all          7          7      0.487      0.965      0.746      0.488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/149         0G    0.04275    0.01416   0.002966         19        416: 100% 2/2 [00:16<00:00,  8.21s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.619          1      0.963      0.271
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/149         0G    0.05593    0.01437   0.004074         22        416: 100% 2/2 [00:16<00:00,  8.03s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.619          1      0.963      0.271
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/149         0G    0.05596    0.01262   0.003649         18        416: 100% 2/2 [00:16<00:00,  8.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.634          1      0.746      0.508
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/149         0G    0.04377    0.01385   0.003366         17        416: 100% 2/2 [00:16<00:00,  8.23s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.634          1      0.746      0.508
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/149         0G    0.04569    0.01524   0.003914         22        416: 100% 2/2 [00:16<00:00,  8.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all          7          7      0.472      0.968      0.746      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/149         0G    0.04443    0.01337   0.003752         21        416: 100% 2/2 [00:16<00:00,  8.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.472      0.968      0.746      0.503
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/149         0G    0.04354    0.01481   0.003538         22        416: 100% 2/2 [00:16<00:00,  8.17s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.992        0.5      0.663      0.438
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/149         0G    0.04753    0.01468   0.004313         19        416: 100% 2/2 [00:17<00:00,  8.88s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.992        0.5      0.663      0.438
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/149         0G    0.04654    0.01173   0.002664         15        416: 100% 2/2 [00:16<00:00,  8.28s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.40s/it]
#                    all          7          7      0.682          1      0.746       0.49
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/149         0G     0.0436    0.01476   0.002595         22        416: 100% 2/2 [00:16<00:00,  8.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all          7          7      0.682          1      0.746       0.49
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/149         0G    0.04364    0.01727   0.005199         25        416: 100% 2/2 [00:20<00:00, 10.01s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.531          1      0.663      0.372
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/149         0G    0.03728    0.01402   0.001734         23        416: 100% 2/2 [00:17<00:00,  8.55s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.531          1      0.663      0.372
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/149         0G    0.04171    0.01428   0.002186         25        416: 100% 2/2 [00:16<00:00,  8.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.917        0.5       0.64      0.274
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/149         0G     0.0443    0.01111   0.002751         18        416: 100% 2/2 [00:16<00:00,  8.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.917        0.5       0.64      0.274
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/149         0G    0.04769    0.01308   0.002531         22        416: 100% 2/2 [00:17<00:00,  8.89s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all          7          7      0.472       0.97       0.69      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/149         0G    0.04256    0.01195   0.002144         15        416: 100% 2/2 [00:16<00:00,  8.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all          7          7      0.472       0.97       0.69      0.424
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/149         0G     0.0462    0.01249   0.003392         15        416: 100% 2/2 [00:16<00:00,  8.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.34s/it]
#                    all          7          7      0.713          1      0.746      0.484
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/149         0G    0.04221    0.01406   0.002514         23        416: 100% 2/2 [00:16<00:00,  8.07s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.39s/it]
#                    all          7          7      0.713          1      0.746      0.484
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/149         0G    0.04847    0.01247    0.00321         20        416: 100% 2/2 [00:15<00:00,  7.84s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.675          1      0.746      0.488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/149         0G    0.03696    0.01021   0.002484         19        416: 100% 2/2 [00:16<00:00,  8.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.38s/it]
#                    all          7          7      0.675          1      0.746      0.488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/149         0G    0.04002    0.01321   0.002315         18        416: 100% 2/2 [00:16<00:00,  8.30s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.39s/it]
#                    all          7          7      0.726          1      0.934      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/149         0G    0.04102     0.0117    0.00187         19        416: 100% 2/2 [00:16<00:00,  8.04s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.726          1      0.934      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/149         0G    0.04198     0.0121   0.002747         22        416: 100% 2/2 [00:17<00:00,  8.85s/it]
# ...
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.32s/it]
#                    all          7          7      0.679      0.984      0.746      0.417
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     113/149         0G    0.03961    0.01186    0.00188         18        416: 100% 2/2 [00:16<00:00,  8.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.39s/it]
#                    all          7          7      0.686      0.997      0.746      0.452
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     114/149         0G    0.04098     0.0131   0.002172         24        416: 100% 2/2 [00:16<00:00,  8.09s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.686      0.997      0.746      0.452
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     115/149         0G    0.03867     0.0138   0.003425         21        416: 100% 2/2 [00:16<00:00,  8.38s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.668      0.966      0.746      0.406
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     116/149         0G    0.03798     0.0133   0.001512         26        416: 100% 2/2 [00:16<00:00,  8.24s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.668      0.966      0.746      0.406
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     117/149         0G    0.03812    0.01124   0.001666         23        416: 100% 2/2 [00:16<00:00,  8.26s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.558      0.981      0.746        0.4
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     118/149         0G    0.04051   0.009867   0.002096         17        416: 100% 2/2 [00:17<00:00,  8.81s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.558      0.981      0.746        0.4
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     119/149         0G    0.04168    0.01276   0.002458         21        416: 100% 2/2 [00:16<00:00,  8.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.50s/it]
#                    all          7          7      0.661      0.987      0.746      0.496
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     120/149         0G    0.03317    0.01164   0.002053         16        416: 100% 2/2 [00:16<00:00,  8.40s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all          7          7      0.661      0.987      0.746      0.496
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     121/149         0G     0.0354    0.01224   0.001653         22        416: 100% 2/2 [00:16<00:00,  8.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7       0.68          1      0.746      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     122/149         0G    0.03564    0.01083    0.00267         17        416: 100% 2/2 [00:16<00:00,  8.42s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7       0.68          1      0.746      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     123/149         0G    0.03382    0.01296   0.001709         30        416: 100% 2/2 [00:16<00:00,  8.30s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.41s/it]
#                    all          7          7      0.662          1      0.746      0.462
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     124/149         0G    0.03639    0.01233   0.001406         26        416: 100% 2/2 [00:20<00:00, 10.04s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.662          1      0.746      0.462
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     125/149         0G    0.03892    0.01255   0.002093         25        416: 100% 2/2 [00:18<00:00,  9.26s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.672          1      0.746      0.465
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     126/149         0G    0.03867    0.01237   0.002756         20        416: 100% 2/2 [00:17<00:00,  8.52s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.672          1      0.746      0.465
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     127/149         0G    0.03701    0.01078   0.003525         18        416: 100% 2/2 [00:17<00:00,  8.56s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.672          1      0.746      0.459
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     128/149         0G    0.03597    0.01211    0.00174         21        416: 100% 2/2 [00:16<00:00,  8.30s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.672          1      0.746      0.459
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     129/149         0G    0.03192    0.01379   0.002128         24        416: 100% 2/2 [00:16<00:00,  8.25s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all          7          7      0.674          1      0.746      0.452
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     130/149         0G    0.03515    0.01155   0.001294         23        416: 100% 2/2 [00:16<00:00,  8.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.674          1      0.746      0.452
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     131/149         0G    0.03782    0.01169   0.002103         24        416: 100% 2/2 [00:17<00:00,  8.64s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.676          1      0.746      0.452
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     132/149         0G    0.02991    0.01165   0.001308         19        416: 100% 2/2 [00:17<00:00,  8.84s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all          7          7      0.676          1      0.746      0.452
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     133/149         0G    0.03193    0.01065   0.001945         21        416: 100% 2/2 [00:16<00:00,  8.23s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.48s/it]
#                    all          7          7      0.684          1      0.746      0.451
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     134/149         0G    0.03118   0.009386   0.001714         14        416: 100% 2/2 [00:16<00:00,  8.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.37s/it]
#                    all          7          7      0.684          1      0.746      0.451
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     135/149         0G    0.03429    0.01062    0.00127         21        416: 100% 2/2 [00:16<00:00,  8.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7      0.679          1      0.746       0.44
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     136/149         0G    0.03947    0.01102   0.002572         14        416: 100% 2/2 [00:16<00:00,  8.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.46s/it]
#                    all          7          7      0.679          1      0.746       0.44
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     137/149         0G    0.03916    0.01086   0.001934         20        416: 100% 2/2 [00:16<00:00,  8.45s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7       0.68          1      0.746      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     138/149         0G    0.03631    0.01103   0.006176         23        416: 100% 2/2 [00:16<00:00,  8.36s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7       0.68          1      0.746      0.434
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     139/149         0G    0.03406    0.01103   0.001358         24        416: 100% 2/2 [00:17<00:00,  8.98s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.682          1      0.746      0.467
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     140/149         0G    0.03434    0.01016   0.001208         21        416: 100% 2/2 [00:16<00:00,  8.20s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.43s/it]
#                    all          7          7      0.682          1      0.746      0.467
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     141/149         0G     0.0331    0.01075   0.001961         18        416: 100% 2/2 [00:16<00:00,  8.46s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.646          1      0.746      0.468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     142/149         0G     0.0327    0.01066   0.001858         24        416: 100% 2/2 [00:16<00:00,  8.39s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.646          1      0.746      0.468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     143/149         0G    0.03669    0.01226   0.002705         21        416: 100% 2/2 [00:17<00:00,  8.53s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.685          1      0.746      0.479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     144/149         0G    0.03032    0.01283    0.00221         25        416: 100% 2/2 [00:16<00:00,  8.41s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.42s/it]
#                    all          7          7      0.685          1      0.746      0.479
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     145/149         0G    0.03241    0.01084    0.00154         18        416: 100% 2/2 [00:16<00:00,  8.32s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.47s/it]
#                    all          7          7      0.683          1      0.746      0.474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     146/149         0G    0.03099    0.01048   0.002095         26        416: 100% 2/2 [00:17<00:00,  8.91s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.45s/it]
#                    all          7          7      0.683          1      0.746      0.474
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     147/149         0G    0.03423    0.01188   0.002197         22        416: 100% 2/2 [00:16<00:00,  8.35s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all          7          7      0.686          1      0.746      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     148/149         0G    0.03273   0.009775   0.003129         15        416: 100% 2/2 [00:16<00:00,  8.31s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.44s/it]
#                    all          7          7      0.686          1      0.746      0.476
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     149/149         0G    0.02965    0.01202   0.001164         20        416: 100% 2/2 [00:16<00:00,  8.32s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.38s/it]
#                    all          7          7      0.684          1      0.746      0.488
#
# 150 epochs completed in 0.774 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.3MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.36s/it]
#                    all          7          7      0.633          1      0.746      0.508
#                  Haima          7          6      0.787          1      0.995      0.718
#                 Others          7          1      0.478          1      0.497      0.298
# Results saved to runs/train/exp

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 416 --conf 0.1 --source {dataset.location}/test/images

# Display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('/content/yolov5/runs/detect/exp/*.jpg'): #assuming JPG
    display(Image(filename=imageName))
    print("\n")
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/datasets/My_Face_Detection-1/test/images, data=data/coco128.yaml, imgsz=[416, 416], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-180-g82bec4c Python-3.7.14 torch-1.12.1+cu113 CPU
#
# Traceback (most recent call last):
#   File "detect.py", line 258, in <module>
#     main(opt)
#   File "detect.py", line 253, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "detect.py", line 95, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/content/yolov5/models/common.py", line 340, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#   File "/content/yolov5/models/experimental.py", line 79, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 699, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 230, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 211, in __init__
#     super(_open_file, self).__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train/exp/weights/best.pt'

# %%
# Export the model's weights for future use
from google.colab import files
files.download('./runs/train/exp/weights/best.pt')

# %%
# Below are the downloaded model's weights
# https://drive.google.com/file/d/1cHJRmtc4XCcxJwWAMSUv3gFhl7JdZFUn/view?usp=sharing
